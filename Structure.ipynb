# %%
import os

# %%
project_folder = r"D:/GitHub/GML_Project"
os.chdir(project_folder)

try:
    os.chdir(r"./Pictures/Tierbilder_Dataset_Train_Eval/Images/")
except FileNotFoundError:
    print("The path doesn't exist.")
print("[INFO] Preparing the structer of the pictures folder.")
try:
    os.mkdir(r"./Duplicate")
except :
    pass

for dire in os.listdir(os.getcwd()):
    if (dire == "Duplicate"):
        continue
    try:
        os.mkdir(os.path.join(dire) + r"/Train/")
    except FileNotFoundError:
        print("\tThe directory couldn't be created because the directory doesn't exist.")
    except FileExistsError:
        print(f"\t{dire}-Train folder already created.")
    
    try:
        os.mkdir(os.path.join(dire) + r"/Evaluation/")
    except FileNotFoundError:
        print("\tThe directory couldn't be created because the directory doesn't exist.")
    except FileExistsError:
        print(f"\t{dire}-Evaluation folder already created.")
# Out:
# [INFO] Preparing the training and evaluation directory.
# 	000000001-butterfly-Train folder already created.
# 	000000001-butterfly-Evaluation folder already created.
# 	000000002-cat-Train folder already created.
# 	000000002-cat-Evaluation folder already created.
# 	000000003-chicken-Train folder already created.
# 	000000003-chicken-Evaluation folder already created.
# 	000000004-cow-Train folder already created.
# 	000000004-cow-Evaluation folder already created.
# 	000000005-dog-Train folder already created.
# 	000000005-dog-Evaluation folder already created.
# 	000000006-elephant-Train folder already created.
# 	000000006-elephant-Evaluation folder already created.
# 	000000007-horse-Train folder already created.
# 	000000007-horse-Evaluation folder already created.
# 	000000008-sheep-Train folder already created.
# 	000000008-sheep-Evaluation folder already created.
# 	000000009-spider-Train folder already created.
# 	000000009-spider-Evaluation folder already created.
# 	000000010-squirrel-Train folder already created.
# 	000000010-squirrel-Evaluation folder already created.
